# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor
from sklearn import metrics

# %%
data_sets=pd.read_csv('Train.csv')

# %%
data_sets.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
data_sets['Item_Fat_Content'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       Low Fat
# 1       Regular
# 2       Low Fat
# 3       Regular
# 4       Low Fat
#          ...
# 8518    Low Fat
# 8519    Regular
# 8520    Low Fat
# 8521    Regular
# 8522    Low Fat
# Name: Item_Fat_Content, Length: 8523, dtype: object>

# %%
data_sets['Item_Fat_Content']
# Out:
# 0       Low Fat
# 1       Regular
# 2       Low Fat
# 3       Regular
# 4       Low Fat
#          ...
# 8518    Low Fat
# 8519    Regular
# 8520    Low Fat
# 8521    Regular
# 8522    Low Fat
# Name: Item_Fat_Content, Length: 8523, dtype: object

# %%
data_sets.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
#handling missing values
#mean->average Value
#mode->most repeated val
# Out:
#   Cell In[15], line 2
#     mean->average Value
#         ^
# SyntaxError: invalid syntax

# %%
#handle missing values
data_sets['Item_Weight'].mean()
# Out:
# np.float64(12.857645184135976)

# %%
data_sets['Item_Weight'].fillna(data_sets['Item_Weight'].mean(),inplace=True)

# %%
data_sets.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
#replacing the outletsize with mode
mode_of_outlet_size=data_sets.pivot_table(values='Outlet_Size',columns='Outlet_Type',aggfunc=(lambda x:x.mode()[0]))

# %%
print(mode_of_outlet_size)
# Out:
# Outlet_Type Grocery Store Supermarket Type1 Supermarket Type2  \
# Outlet_Size         Small             Small            Medium
#
# Outlet_Type Supermarket Type3
# Outlet_Size            Medium

# %%
missing=data_sets['Outlet_Size'].isnull().sum()

# %%
print(missing)
# Out:
# 2410

# %%
data_sets.loc[missing, 'Outlet_Size'] = (
    data_sets.loc[missing, 'Outlet_Type']
    .map(mode_of_outlet_size)
)
print(data_sets['Outlet_Size'].isnull().sum())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 3
#       1 data_sets.loc[missing, 'Outlet_Size'] = (
#       2     data_sets.loc[missing, 'Outlet_Type']
# ----> 3     .map(mode_of_outlet_size)
#       4 )
#       5 print(data_sets['Outlet_Size'].isnull().sum())
#
# AttributeError: 'str' object has no attribute 'map'

# %%
data_sets.loc[missing, 'Outlet_Size'] = (
    data_sets.loc[missing, 'Outlet_Type']
    .map(mode_of_outlet_size)
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 3
#       1 data_sets.loc[missing, 'Outlet_Size'] = (
#       2     data_sets.loc[missing, 'Outlet_Type']
# ----> 3     .map(mode_of_outlet_size)
#       4 )
#
# AttributeError: 'str' object has no attribute 'map'
