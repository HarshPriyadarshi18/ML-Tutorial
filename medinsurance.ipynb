# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
data_sets=pd.read_csv('insurance.csv')

# %%
data_sets.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
data_sets.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
data_sets['region'].value_counts()
# Out:
# region
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: count, dtype: int64

# %%
# distribution of age value
sns.set()
plt.figure(figsize=(6,6))
sns.distplot(data_sets['age'])
plt.title('Age Distribution')
plt.show()
# Out:
# C:\Users\hpriy\AppData\Local\Temp\ipykernel_27892\1243922528.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_sets['age'])

# %%
# Gender column
plt.figure(figsize=(6,6))
sns.countplot(x='sex', data=data_sets)
plt.title('Sex Distribution')
plt.show()

# %%
data_sets['sex'].replace({'male':0,'female':1},inplace=True  )
# Out:
# C:\Users\hpriy\AppData\Local\Temp\ipykernel_27892\3717773387.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_sets['sex'].replace({'male':0,'female':1},inplace=True  )
# C:\Users\hpriy\AppData\Local\Temp\ipykernel_27892\3717773387.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ...

# %%
data_sets['smoker'].replace({'yes':0,'no':1},inplace=True)

# %%
X=data_sets.drop(columns='charges',axis=1
                )

# %%
Y=  data_sets['charges']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=2)

# %%
# encoding sex column
data_sets.replace({'sex':{'male':0,'female':1}}, inplace=True)

3 # encoding 'smoker' column
data_sets.replace({'smoker':{'yes':0,'no':1}}, inplace=True)

# encoding 'region' column
data_sets.replace({'region':{'southeast':0,'southwest':1,'northeast':2,'northwest':3}}, inplace=True)
# Out:
# C:\Users\hpriy\AppData\Local\Temp\ipykernel_27892\1095104649.py:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data_sets.replace({'smoker':{'yes':0,'no':1}}, inplace=True)
# C:\Users\hpriy\AppData\Local\Temp\ipykernel_27892\1095104649.py:8: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data_sets.replace({'region':{'southeast':0,'southwest':1,'northeast':2,'northwest':3}}, inplace=True)

# %%
X = data_sets.drop(columns='charges', axis=1)
Y = data_sets['charges']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=2)

# %%
# loading the Linear Regression model
regressor = LinearRegression()

# %%
regressor.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
# prediction on training data
training_data_prediction =regressor.predict(X_train)
accuracy_scor=accuracy_score(Y_train, training_data_prediction)
print('Accuracy score of training data : ', accuracy_scor)

# %%
# R squared value
r2_train = metrics.r2_score(Y_train, training_data_prediction)

print('R squared vale : ', r2_train)
# Out:
# R squared vale :  0.751505643411174

# %%
# prediction on test data
test_data_prediction =regressor.predict(X_test)

# %%
# R squared value
r2_test = metrics.r2_score(Y_test, test_data_prediction)
print('R squared vale : ', r2_test)
# Out:
# R squared vale :  0.7447273869684077

# %%
input_data = (31,1,25.74,0,1,0)

# changing input_data to a numpy array
input_data_as_numpy_array = np.asarray(input_data)

# reshape the array
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = regressor.predict(input_data_reshaped)
print(prediction)

print('The insurance cost is USD ', prediction[0])
# Out:
# [3760.0805765]
# The insurance cost is USD  3760.0805764960587
# C:\Users\hpriy\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
